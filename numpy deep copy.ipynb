# %%
import numpy as np

# %%
x = np.array([1,2,3])
print(x)
# Out:
# [1 2 3]

# %%
y = x
y_copy = np.copy(x)

# %%
y
# Out:
# array([1, 2, 3])

# %%
x[0]  = -2  # teraz dokonam zmiany w zmiennej y

# %%
y
# Out:
# array([-2,  2,  3])

# %%
x
# Out:
# array([-2,  2,  3])

# %%
id(x), id(y)
# Out:
# (136176669393520, 136176669393520)

# %%
y_copy
# Out:
# array([1, 2, 3])

# %%
y_copy[0] = -3

# %%
x, y
# Out:
# (array([-2,  2,  3]), array([-2,  2,  3]))

# %%
y_copy
# Out:
# array([-3,  2,  3])

# %%
id(y_copy)
# Out:
# 136176669323984

# %%
import pandas as pd

# %%
series_original = pd.Series([1,2,3])

# %%
series_copy = pd.Series(deepcopy(series_original.to_dict()))
